# %%
import setup

# %%
import numpy as np
import torch
import torchvision.transforms.functional as F
from torchvision.ops import box_convert
from pathlib import Path

from data.utkface_dataset import UTKFaceDataset
from torchvision.transforms import v2 as T

# %%
path = Path("../datasets/utkface")

for file in path.glob("*.jpg"):
    labels = file.name.split("_")

    if len(labels) != 4:
        # remove file
        print(f"removing {file.name}")
        file.unlink()
# Out:
# removing 1_0_20161219205817093.jpg.chip.jpg

# %%
dataset = UTKFaceDataset("../datasets/utkface")

# %%
loader = iter(dataset)

# %%
import matplotlib.pyplot as plt


def show(imgs):
    if not isinstance(imgs, list):
        imgs = [imgs]
    fix, axs = plt.subplots(ncols=len(imgs), squeeze=False)
    for i, img in enumerate(imgs):
        img = img.detach()
        img = F.to_pil_image(img)
        axs[0, i].imshow(np.asarray(img))
        axs[0, i].set(xticklabels=[], yticklabels=[], xticks=[], yticks=[])

# %%
IMAGE_SIZE = 200

transforms = T.Compose(
    [
        T.RandomHorizontalFlip(p=0.5),
        T.RandomRotation(degrees=[-30, 30]),
        T.RandomResizedCrop(IMAGE_SIZE, scale=(0.75, 1.25), ratio=(1.0, 1.0), antialias=True),
        T.RandomGrayscale(0.5)
    ]
)

for i in range(5):
    sample = next(loader)
    transformed = transforms(sample)

    show([sample["image"], transformed["image"]])

# %%
model =  instantiate(cfg.model)
data = instantiate(cfg.data)

new_params = [name for name, param in model.named_parameters()]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 model =  instantiate(cfg.model)
#       2 data = instantiate(cfg.data)
#       4 new_params = [name for name, param in model.named_parameters()]
#
# NameError: name 'instantiate' is not defined

# %%
data.setup()
loader = iter(data.val_dataloader())

# %%
for i in range(1000):
    batch = next(loader)

    for target in batch[1]:
        print(target['type'])
# Out:
# snow
# rain
# fog
# fog
# rain
# snow
# fog
# fog
# snow
# fog
# rain
# snow
# snow
# snow
# rain
# snow
# rain
# fog
# snow
# snow
# snow
# fog
# fog
# rain
# rain
# snow
# rain
# snow
# snow
# snow
# rain
# rain
# snow
# rain
# fog
# fog
# fog
# snow
# snow
# fog
# snow
# rain
# rain
# fog
# rain
# fog
# fog
# fog
# fog
# snow
# fog
# rain
# fog
# fog
# snow
# rain
# rain
# rain
# rain
# rain
# fog
# rain
# snow
# snow
# snow
# fog
# snow
# rain
# snow
# fog
# rain
# snow
# rain
# snow
# fog
# snow
# fog
# rain
# rain
# snow
# rain
# rain
# fog
# snow
# rain
# snow
# snow
# fog
# fog
# snow
# fog
# fog
# rain
# fog
# snow
# rain
# rain
# rain
# snow
# fog
# fog
# rain
# snow
# fog
# fog
# rain
# fog
# snow
# snow
# snow
# fog
# rain
# snow
# fog
# fog
# snow
# rain
# snow
# fog
# snow
# fog
# fog
# snow
# snow
# snow
# fog
# snow
# rain
# snow
# rain
# fog
# rain
# snow
# snow
# fog
# fog
# snow
# fog
# snow
# snow
# rain
# rain
# rain
# snow
# snow
# snow
# rain
# snow
# fog
# ...
